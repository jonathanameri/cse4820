# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
# load raw data
xdat = np.loadtxt('xvals.dat')
ydat = np.loadtxt('yvals.dat')

# define training data
# NOTE: In this exercise we are not measuring performance
# or performing model selection, so for demonstration purposes
# we will use all of the data for training and there is no test set.
X_train = xdat
y_train = ydat

# %%
# fit the linear Support Vector Classifier
clf = SVC(C=1e3, kernel='linear', tol=1e-8, verbose=True)
clf.fit(X_train, y_train)
# Out:
# [LibSVM].................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................*..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 296450
# obj = -31078.277144, rho = -2.081379
# nSV = 33, nBSV = 30
# Total nSV = 33
# SVC(C=1000.0, kernel='linear', tol=1e-08, verbose=True)

# %%
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors from each class:', clf.n_support_)
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w) # margin of separation
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.set_title("Decision Boundary at C=1e3")
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors from each class: [16 17]

# %%
print(margin)
print(w)
print(b)
# Out:
# 0.9603131248204164
# [0.55976542 0.87808008]
# -2.0813791769206524

# %%
# fit the linear Support Vector Classifier
clf = SVC(C=1, kernel='linear', tol=1e-8, verbose=True)
clf.fit(X_train, y_train)
# Out:
# [LibSVM]..*
# optimization finished, #iter = 251
# obj = -31.602949, rho = -1.644525
# nSV = 33, nBSV = 31
# Total nSV = 33
# SVC(C=1, kernel='linear', tol=1e-08, verbose=True)

# %%
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors from each class:', clf.n_support_)
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w) # margin of separation
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.set_title("Decision Boundary at C=1")
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors from each class: [16 17]

# %%
print(margin)
print(w)
print(b)
# Out:
# 1.122170207116113
# [0.48022148 0.75066686]
# -1.6445252371736157

# %%
# fit the linear Support Vector Classifier
clf = SVC(C=1e-3, kernel='linear', tol=1e-8, verbose=True)
clf.fit(X_train, y_train)
# Out:
# [LibSVM]*
# optimization finished, #iter = 49
# obj = -0.087600, rho = -0.836889
# nSV = 98, nBSV = 98
# Total nSV = 98
# SVC(C=0.001, kernel='linear', tol=1e-08, verbose=True)

# %%
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors from each class:', clf.n_support_)
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w) # margin of separation
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.set_title("Decision Boundary at C=1e-3")
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors from each class: [49 49]

# %%
print(margin)
print(w)
print(b)
# Out:
# 6.93374169241712
# [0.09620674 0.10744453]
# -0.8368885305253787

# %% [markdown]
# ## Question 3

# %% [markdown]
# 3a. The margin is defined as margin = 1/np.linalg.norm(w)

# %% [markdown]
# 3b. The decision boundary is defined as xx2 = (-w[0]/w[1])*xx1 - b/w[1] <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;This can be rewritten as w[1]xx2 + w[0]xx1 + b = 0 -> (w^T)*x + b = 0

# %% [markdown]
# 3c. With respect to the decision boundary and margin, data points incorrectly classified and inside the margin are support vectors

# %% [markdown]
# ## Question 4

# %% [markdown]
# 4a. Examining the decision boundary when C = 1, the margin of separation = 1.122170207116113 <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Meanwhile the entire margin is of size 2 * 1.122170207116113 = 2.244340414232226

# %% [markdown]
# 4b. When C = 1, there are 16 support vectors in Class 1, and 17 in Class 2. Cumulatively there are 33 support vectors

# %% [markdown]
# 4c. See Above Figures

# %% [markdown]
# 4d. Examining the impact of C on the decision boundary, it becomes clear that as C inreases the margin decreases and vice versa
